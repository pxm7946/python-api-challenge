# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country=citipy.nearest_city(lat_lng[0], lat_lng [1]).country_code
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country.upper())

# Print the city count to confirm sufficient count
len(cities)

# Print the country count to confirm sufficient count
len (countries)
# Out:
# 610

# %%
#Create a dataframe to store the data
city_weather = pd.DataFrame({'City': cities, 'Cloudiness': "", 'Country': countries, 'Date': "",
                            'Humidity': "", 'Lat': "", 'Lng': "", 'Max Temp': "", 'Windspeed': ""})

#Preview the dataframe
city_weather.head()
# Out:
#            City Cloudiness Country Date Humidity Lat Lng Max Temp Windspeed
# 0       beterou                 BJ
# 1    sao filipe                 CV
# 2           gat                 LY
# 3       mataura                 PF
# 4  punta arenas                 CL

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Variables to keep track of response number
record_num = 1
record_set = 1

#Base url to make the api call
base_url = 'http://api.openweathermap.org/data/2.5/weather?units=imperial&q='

#Run the API call for each city
print('''
-----------------------------
Beginning Data Retrieval
-----------------------------''')
for index, row in city_weather.iterrows(): 
    #Create the query url for the API call
    query_url = base_url + row['City'] + ',' + row['Country'] + '&APPID=' + weather_api_key

    
    #API call
    response = requests.get(query_url).json()
    
    #Exception script in case the city is not found by the API call
    try: 
        #Meassage to alert the user that the data is being retrieved
        print(f'Processing Weather Data for Record {record_num} of Set {record_set} | {response["name"]}')
        
        #Input data into the dataframe
        city_weather.loc[index, 'Cloudiness'] = response['clouds']['all']
        city_weather.loc[index, 'Date'] = response['dt']
        city_weather.loc[index, 'Humidity'] = response['main']['humidity']
        city_weather.loc[index, 'Lat'] = response['coord']['lat']
        city_weather.loc[index, 'Lng'] = response['coord']['lon']
        city_weather.loc[index, 'Max Temp'] = response['main']['temp_max']
        city_weather.loc[index, 'Windspeed'] = response['wind']['speed']
        
        #Increase the record count
        record_num += 1
        
    except (KeyError, IndexError):
        print("City not found....Skipping............")
    
    #If statement to handle the API call limits
    if record_num == 51:
        record_set += 1
        record_num = 1
        time.sleep(60)
        
print('''
-----------------------------
Data Retrival Complete
-----------------------------''')
# Out:
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
# Processing Weather Data for Record 1 of Set 1 | Bétérou
# Processing Weather Data for Record 2 of Set 1 | São Filipe
# City not found....Skipping............
# City not found....Skipping............
# Processing Weather Data for Record 3 of Set 1 | Punta Arenas
# Processing Weather Data for Record 4 of Set 1 | Dunedin
# Processing Weather Data for Record 5 of Set 1 | Chik
# City not found....Skipping............
# Processing Weather Data for Record 6 of Set 1 | Kota Bharu
# Processing Weather Data for Record 7 of Set 1 | Padang
# Processing Weather Data for Record 8 of Set 1 | Ust'-Uda
# City not found....Skipping............
# Processing Weather Data for Record 9 of Set 1 | San Pedro de Ycuamandiyú
# Processing Weather Data for Record 10 of Set 1 | Hasaki
# Processing Weather Data for Record 11 of Set 1 | Riyadh
# Processing Weather Data for Record 12 of Set 1 | Yellowknife
# Processing Weather Data for Record 13 of Set 1 | Rio Grande
# Processing Weather Data for Record 14 of Set 1 | Burnie
# Processing Weather Data for Record 15 of Set 1 | Saint-Louis
# Processing Weather Data for Record 16 of Set 1 | Rikitea
# Processing Weather Data for Record 17 of Set 1 | Puerto Ayora
# Processing Weather Data for Record 18 of Set 1 | Ushuaia
# Processing Weather Data for Record 19 of Set 1 | Port Alfred
# Processing Weather Data for Record 20 of Set 1 | Dauriya
# Processing Weather Data for Record 21 of Set 1 | Diamantino
# Processing Weather Data for Record 22 of Set 1 | Arrondissement de Lannion
# City not found....Skipping............
# Processing Weather Data for Record 23 of Set 1 | Kapaa
# Processing Weather Data for Record 24 of Set 1 | Mar del Plata
# Processing Weather Data for Record 25 of Set 1 | Partenit
# Processing Weather Data for Record 26 of Set 1 | Tuktoyaktuk
# Processing Weather Data for Record 27 of Set 1 | Vaini
# Processing Weather Data for Record 28 of Set 1 | Hermanus
# Processing Weather Data for Record 29 of Set 1 | Vestmannaeyjar
# Processing Weather Data for Record 30 of Set 1 | Matara
# City not found....Skipping............
# Processing Weather Data for Record 31 of Set 1 | Govlyar
# Processing Weather Data for Record 32 of Set 1 | Henties Bay
# Processing Weather Data for Record 33 of Set 1 | Saldanha
# Processing Weather Data for Record 34 of Set 1 | Hirara
# Processing Weather Data for Record 35 of Set 1 | Mayo
# City not found....Skipping............
# Processing Weather Data for Record 36 of Set 1 | Kyshtovka
# Processing Weather Data for Record 37 of Set 1 | Lagoa
# Processing Weather Data for Record 38 of Set 1 | Kaitangata
# Processing Weather Data for Record 39 of Set 1 | Oron
# Processing Weather Data for Record 40 of Set 1 | Cape Town
# Processing Weather Data for Record 41 of Set 1 | Orotukan
# Processing Weather Data for Record 42 of Set 1 | Nizhniy Kuranakh
# Processing Weather Data for Record 43 of Set 1 | Jimeta
# Processing Weather Data for Record 44 of Set 1 | Tiznit Province
# Processing Weather Data for Record 45 of Set 1 | Qaanaaq
# City not found....Skipping............
# Processing Weather Data for Record 46 of Set 1 | Mumford
# Processing Weather Data for Record 47 of Set 1 | Upernavik
# Processing Weather Data for Record 48 of Set 1 | Hobart
# Processing Weather Data for Record 49 of Set 1 | Atuona
# City not found....Skipping............
# Processing Weather Data for Record 50 of Set 1 | Manyana
# Processing Weather Data for Record 1 of Set 2 | Acapulco de Juárez
# Processing Weather Data for Record 2 of Set 2 | Haines Junction
# Processing Weather Data for Record 3 of Set 2 | Linguère
# Processing Weather Data for Record 4 of Set 2 | Natitingou
# Processing Weather Data for Record 5 of Set 2 | Sennar
# Processing Weather Data for Record 6 of Set 2 | Mouila
# Processing Weather Data for Record 7 of Set 2 | Albany
# Processing Weather Data for Record 8 of Set 2 | Cayenne
# City not found....Skipping............
# Processing Weather Data for Record 9 of Set 2 | Narsaq
# Processing Weather Data for Record 10 of Set 2 | Ascoli Piceno
# Processing Weather Data for Record 11 of Set 2 | Avarua
# Processing Weather Data for Record 12 of Set 2 | Ilulissat
# Processing Weather Data for Record 13 of Set 2 | Ponta do Sol
# Processing Weather Data for Record 14 of Set 2 | Provideniya
# Processing Weather Data for Record 15 of Set 2 | Troitsko-Pechorsk
# Processing Weather Data for Record 16 of Set 2 | Dikson
# Processing Weather Data for Record 17 of Set 2 | Port Lincoln
# Processing Weather Data for Record 18 of Set 2 | Clyde River
# Processing Weather Data for Record 19 of Set 2 | Āsosa
# Processing Weather Data for Record 20 of Set 2 | Saskylakh
# Processing Weather Data for Record 21 of Set 2 | Saint-Philippe
# Processing Weather Data for Record 22 of Set 2 | Biak
# City not found....Skipping............
# Processing Weather Data for Record 23 of Set 2 | Nantucket
# Processing Weather Data for Record 24 of Set 2 | Jamestown
# Processing Weather Data for Record 25 of Set 2 | Celendín
# Processing Weather Data for Record 26 of Set 2 | Bethel
# Processing Weather Data for Record 27 of Set 2 | Faanui
# Processing Weather Data for Record 28 of Set 2 | Taoudenni
# Processing Weather Data for Record 29 of Set 2 | Harlingen
# Processing Weather Data for Record 30 of Set 2 | Puerto Madero
# Processing Weather Data for Record 31 of Set 2 | Antofagasta
# Processing Weather Data for Record 32 of Set 2 | Chui
# Processing Weather Data for Record 33 of Set 2 | Severo-Kuril'sk
# Processing Weather Data for Record 34 of Set 2 | Longyearbyen
# Processing Weather Data for Record 35 of Set 2 | Sozopol
# City not found....Skipping............
# Processing Weather Data for Record 36 of Set 2 | Nanortalik
# Processing Weather Data for Record 37 of Set 2 | Barkhan
# Processing Weather Data for Record 38 of Set 2 | Ishigaki
# Processing Weather Data for Record 39 of Set 2 | Bambous Virieux
# Processing Weather Data for Record 40 of Set 2 | Iralaya
# Processing Weather Data for Record 41 of Set 2 | Moree
# City not found....Skipping............
# Processing Weather Data for Record 42 of Set 2 | Bathsheba
# Processing Weather Data for Record 43 of Set 2 | Hofn
# Processing Weather Data for Record 44 of Set 2 | Bandarbeyla
# Processing Weather Data for Record 45 of Set 2 | Port Elizabeth
# Processing Weather Data for Record 46 of Set 2 | Fort Nelson
# Processing Weather Data for Record 47 of Set 2 | Salym
# Processing Weather Data for Record 48 of Set 2 | Touros
# Processing Weather Data for Record 49 of Set 2 | Bluff
# Processing Weather Data for Record 50 of Set 2 | Talnakh
# Processing Weather Data for Record 1 of Set 3 | Olinda
# Processing Weather Data for Record 2 of Set 3 | Kuril'sk
# Processing Weather Data for Record 3 of Set 3 | Harper
# Processing Weather Data for Record 4 of Set 3 | Sterling
# Processing Weather Data for Record 5 of Set 3 | Victoria
# Processing Weather Data for Record 6 of Set 3 | Georgetown
# Processing Weather Data for Record 7 of Set 3 | Sovetskiy
# Processing Weather Data for Record 8 of Set 3 | Ambon City
# Processing Weather Data for Record 9 of Set 3 | Dzaoudzi
# Processing Weather Data for Record 10 of Set 3 | New Norfolk
# Processing Weather Data for Record 11 of Set 3 | Nemuro
# Processing Weather Data for Record 12 of Set 3 | Norman Wells
# Processing Weather Data for Record 13 of Set 3 | Lázaro Cárdenas
# Processing Weather Data for Record 14 of Set 3 | Lerwick
# City not found....Skipping............
# Processing Weather Data for Record 15 of Set 3 | Seydi
# Processing Weather Data for Record 16 of Set 3 | De-Kastri
# Processing Weather Data for Record 17 of Set 3 | Sicuani
# City not found....Skipping............
# Processing Weather Data for Record 18 of Set 3 | Samoded
# Processing Weather Data for Record 19 of Set 3 | Nikolskoye
# Processing Weather Data for Record 20 of Set 3 | Chongwe
# Processing Weather Data for Record 21 of Set 3 | Luanda
# City not found....Skipping............
# Processing Weather Data for Record 22 of Set 3 | Carnarvon
# Processing Weather Data for Record 23 of Set 3 | Cachoeira do Sul
# Processing Weather Data for Record 24 of Set 3 | Kibaya
# Processing Weather Data for Record 25 of Set 3 | Naze
# Processing Weather Data for Record 26 of Set 3 | Erenhot
# Processing Weather Data for Record 27 of Set 3 | Zorritos
# Processing Weather Data for Record 28 of Set 3 | Katsuura
# Processing Weather Data for Record 29 of Set 3 | Sugar Land
# Processing Weather Data for Record 30 of Set 3 | Mahanoro
# Processing Weather Data for Record 31 of Set 3 | Arawa
# Processing Weather Data for Record 32 of Set 3 | Kahului
# Processing Weather Data for Record 33 of Set 3 | Russell
# Processing Weather Data for Record 34 of Set 3 | Río Gallegos
# Processing Weather Data for Record 35 of Set 3 | Baihar
# Processing Weather Data for Record 36 of Set 3 | Coolum Beach
# Processing Weather Data for Record 37 of Set 3 | Pacific Grove
# City not found....Skipping............
# City not found....Skipping............
# City not found....Skipping............
# Processing Weather Data for Record 38 of Set 3 | Barrow
# Processing Weather Data for Record 39 of Set 3 | Umm Kaddadah
# Processing Weather Data for Record 40 of Set 3 | Ust-Nera
# Processing Weather Data for Record 41 of Set 3 | Noyabrsk
# Processing Weather Data for Record 42 of Set 3 | Kavieng
# Processing Weather Data for Record 43 of Set 3 | Bredasdorp
# Processing Weather Data for Record 44 of Set 3 | Muros
# Processing Weather Data for Record 45 of Set 3 | Arraial do Cabo
# Processing Weather Data for Record 46 of Set 3 | San Patricio
# Processing Weather Data for Record 47 of Set 3 | Shelopugino
# City not found....Skipping............
# Processing Weather Data for Record 48 of Set 3 | Broken Hill
# Processing Weather Data for Record 49 of Set 3 | Taperoá
# Processing Weather Data for Record 50 of Set 3 | Katobu
# Processing Weather Data for Record 1 of Set 4 | Yumen
# Processing Weather Data for Record 2 of Set 4 | Lomovka
# Processing Weather Data for Record 3 of Set 4 | Ouallam
# Processing Weather Data for Record 4 of Set 4 | Hithadhoo
# Processing Weather Data for Record 5 of Set 4 | Horsham
# Processing Weather Data for Record 6 of Set 4 | Tasiilaq
# Processing Weather Data for Record 7 of Set 4 | Ruwi
# Processing Weather Data for Record 8 of Set 4 | Barentu
# City not found....Skipping............
# Processing Weather Data for Record 9 of Set 4 | Pinawa
# Processing Weather Data for Record 10 of Set 4 | Inverell
# City not found....Skipping............
# Processing Weather Data for Record 11 of Set 4 | Geraldton
# Processing Weather Data for Record 12 of Set 4 | Aksu
# Processing Weather Data for Record 13 of Set 4 | Agadez
# Processing Weather Data for Record 14 of Set 4 | Lebu
# Processing Weather Data for Record 15 of Set 4 | Itoman
# Processing Weather Data for Record 16 of Set 4 | Palmeirais
# Processing Weather Data for Record 17 of Set 4 | Vardø
# Processing Weather Data for Record 18 of Set 4 | Te Anau
# Processing Weather Data for Record 19 of Set 4 | Sandy Bay
# Processing Weather Data for Record 20 of Set 4 | Port Hardy
# Processing Weather Data for Record 21 of Set 4 | Kununurra
# Processing Weather Data for Record 22 of Set 4 | Aklavik
# City not found....Skipping............
# Processing Weather Data for Record 23 of Set 4 | Nacala
# Processing Weather Data for Record 24 of Set 4 | Chapais
# Processing Weather Data for Record 25 of Set 4 | Bacolod City
# City not found....Skipping............
# Processing Weather Data for Record 26 of Set 4 | Sotouboua
# City not found....Skipping............
# Processing Weather Data for Record 27 of Set 4 | Pevek
# Processing Weather Data for Record 28 of Set 4 | Roma
# Processing Weather Data for Record 29 of Set 4 | Mariënburg
# Processing Weather Data for Record 30 of Set 4 | Torbay
# Processing Weather Data for Record 31 of Set 4 | Leningradskiy
# Processing Weather Data for Record 32 of Set 4 | Cherskiy
# Processing Weather Data for Record 33 of Set 4 | Isangel
# Processing Weather Data for Record 34 of Set 4 | Rawson
# Processing Weather Data for Record 35 of Set 4 | Egvekinot
# Processing Weather Data for Record 36 of Set 4 | Cabo San Lucas
# Processing Weather Data for Record 37 of Set 4 | Ribeira Grande
# Processing Weather Data for Record 38 of Set 4 | Peniche
# Processing Weather Data for Record 39 of Set 4 | Butaritari
# Processing Weather Data for Record 40 of Set 4 | Baykit
# Processing Weather Data for Record 41 of Set 4 | Brigantine
# Processing Weather Data for Record 42 of Set 4 | Kuandian
# Processing Weather Data for Record 43 of Set 4 | Husavik
# Processing Weather Data for Record 44 of Set 4 | Soure
# City not found....Skipping............
# Processing Weather Data for Record 45 of Set 4 | Sørland
# Processing Weather Data for Record 46 of Set 4 | Castro
# Processing Weather Data for Record 47 of Set 4 | Ucluelet
# Processing Weather Data for Record 48 of Set 4 | Guerrero Negro
# Processing Weather Data for Record 49 of Set 4 | Cidreira
# Processing Weather Data for Record 50 of Set 4 | Mthatha
# Processing Weather Data for Record 1 of Set 5 | Mpanda
# Processing Weather Data for Record 2 of Set 5 | Kruisfontein
# Processing Weather Data for Record 3 of Set 5 | Sur
# Processing Weather Data for Record 4 of Set 5 | Phan Thiet
# Processing Weather Data for Record 5 of Set 5 | Khatanga
# City not found....Skipping............
# Processing Weather Data for Record 6 of Set 5 | Kilindoni
# Processing Weather Data for Record 7 of Set 5 | Luwuk
# Processing Weather Data for Record 8 of Set 5 | Iqaluit
# Processing Weather Data for Record 9 of Set 5 | Meulaboh
# Processing Weather Data for Record 10 of Set 5 | Gizo Government Station
# Processing Weather Data for Record 11 of Set 5 | Xai-Xai
# Processing Weather Data for Record 12 of Set 5 | Bilibino
# Processing Weather Data for Record 13 of Set 5 | Esperance
# Processing Weather Data for Record 14 of Set 5 | Namatanai
# Processing Weather Data for Record 15 of Set 5 | Maţāy
# Processing Weather Data for Record 16 of Set 5 | Busselton
# City not found....Skipping............
# Processing Weather Data for Record 17 of Set 5 | Klaksvík
# Processing Weather Data for Record 18 of Set 5 | Mitú
# Processing Weather Data for Record 19 of Set 5 | Bougouni
# Processing Weather Data for Record 20 of Set 5 | Hilo
# City not found....Skipping............
# Processing Weather Data for Record 21 of Set 5 | Sambava
# Processing Weather Data for Record 22 of Set 5 | Mikhaylovskaya
# Processing Weather Data for Record 23 of Set 5 | Pangnirtung
# Processing Weather Data for Record 24 of Set 5 | Conceição da Barra
# Processing Weather Data for Record 25 of Set 5 | Vaitape
# Processing Weather Data for Record 26 of Set 5 | Mikuni
# Processing Weather Data for Record 27 of Set 5 | Alta
# City not found....Skipping............
# Processing Weather Data for Record 28 of Set 5 | Liwale
# Processing Weather Data for Record 29 of Set 5 | Kwang Binh
# Processing Weather Data for Record 30 of Set 5 | West Monroe
# Processing Weather Data for Record 31 of Set 5 | Jertih
# Processing Weather Data for Record 32 of Set 5 | Porto Novo
# Processing Weather Data for Record 33 of Set 5 | Necochea
# Processing Weather Data for Record 34 of Set 5 | São Félix do Xingu
# Processing Weather Data for Record 35 of Set 5 | Atasū
# Processing Weather Data for Record 36 of Set 5 | Nyurba
# Processing Weather Data for Record 37 of Set 5 | Catabola
# Processing Weather Data for Record 38 of Set 5 | Gananoque
# Processing Weather Data for Record 39 of Set 5 | Grindavik
# Processing Weather Data for Record 40 of Set 5 | Bengkulu
# Processing Weather Data for Record 41 of Set 5 | Fes
# Processing Weather Data for Record 42 of Set 5 | Hay River
# Processing Weather Data for Record 43 of Set 5 | Demirci
# Processing Weather Data for Record 44 of Set 5 | Laguna
# Processing Weather Data for Record 45 of Set 5 | Smoky Lake
# Processing Weather Data for Record 46 of Set 5 | Vostok
# Processing Weather Data for Record 47 of Set 5 | Oodweyne
# Processing Weather Data for Record 48 of Set 5 | Svetlaya
# Processing Weather Data for Record 49 of Set 5 | Horia
# Processing Weather Data for Record 50 of Set 5 | Salalah
# Processing Weather Data for Record 1 of Set 6 | Fortuna
# Processing Weather Data for Record 2 of Set 6 | Andros Town
# Processing Weather Data for Record 3 of Set 6 | Departamento de Maldonado
# Processing Weather Data for Record 4 of Set 6 | Honningsvåg
# Processing Weather Data for Record 5 of Set 6 | Koslan
# Processing Weather Data for Record 6 of Set 6 | Afyonkarahisar
# Processing Weather Data for Record 7 of Set 6 | Huicungo
# Processing Weather Data for Record 8 of Set 6 | Ukiah
# City not found....Skipping............
# Processing Weather Data for Record 9 of Set 6 | Narón
# Processing Weather Data for Record 10 of Set 6 | Hūn
# City not found....Skipping............
# Processing Weather Data for Record 11 of Set 6 | Parkes
# Processing Weather Data for Record 12 of Set 6 | Ahtopol
# Processing Weather Data for Record 13 of Set 6 | Władysławowo
# Processing Weather Data for Record 14 of Set 6 | Trelew
# Processing Weather Data for Record 15 of Set 6 | Gawler
# Processing Weather Data for Record 16 of Set 6 | Kavaratti
# City not found....Skipping............
# Processing Weather Data for Record 17 of Set 6 | Karratha
# Processing Weather Data for Record 18 of Set 6 | Tegul'det
# Processing Weather Data for Record 19 of Set 6 | Ketchikan
# Processing Weather Data for Record 20 of Set 6 | Santa Maria
# Processing Weather Data for Record 21 of Set 6 | San Cristobal
# Processing Weather Data for Record 22 of Set 6 | Indianola
# Processing Weather Data for Record 23 of Set 6 | Prachatice
# City not found....Skipping............
# Processing Weather Data for Record 24 of Set 6 | Patea
# Processing Weather Data for Record 25 of Set 6 | Correntina
# Processing Weather Data for Record 26 of Set 6 | Quatre Cocos
# Processing Weather Data for Record 27 of Set 6 | Kyzyl-Suu
# Processing Weather Data for Record 28 of Set 6 | Linkou
# Processing Weather Data for Record 29 of Set 6 | Kenai
# Processing Weather Data for Record 30 of Set 6 | Saint Paul Harbor
# City not found....Skipping............
# Processing Weather Data for Record 31 of Set 6 | Bogatynia
# Processing Weather Data for Record 32 of Set 6 | Makakilo City
# Processing Weather Data for Record 33 of Set 6 | Chuzhou
# Processing Weather Data for Record 34 of Set 6 | San Francisco
# Processing Weather Data for Record 35 of Set 6 | Anicuns
# Processing Weather Data for Record 36 of Set 6 | Praia da Vitória
# Processing Weather Data for Record 37 of Set 6 | Balabac
# Processing Weather Data for Record 38 of Set 6 | Tadpatri
# Processing Weather Data for Record 39 of Set 6 | Sobolevo
# Processing Weather Data for Record 40 of Set 6 | Komsomol'skiy
# Processing Weather Data for Record 41 of Set 6 | San Quintín
# Processing Weather Data for Record 42 of Set 6 | Cockburn Town
# Processing Weather Data for Record 43 of Set 6 | Nakamura
# Processing Weather Data for Record 44 of Set 6 | La Sarre
# Processing Weather Data for Record 45 of Set 6 | Pilar
# Processing Weather Data for Record 46 of Set 6 | Rasrā
# Processing Weather Data for Record 47 of Set 6 | Samarai
# City not found....Skipping............
# Processing Weather Data for Record 48 of Set 6 | Pisco
# Processing Weather Data for Record 49 of Set 6 | Dalbandin
# Processing Weather Data for Record 50 of Set 6 | Lavrentiya
# Processing Weather Data for Record 1 of Set 7 | Lorengau
# Processing Weather Data for Record 2 of Set 7 | Bontang
# Processing Weather Data for Record 3 of Set 7 | La Ronge
# Processing Weather Data for Record 4 of Set 7 | Tiksi
# City not found....Skipping............
# Processing Weather Data for Record 5 of Set 7 | Tadine
# Processing Weather Data for Record 6 of Set 7 | San Miguel
# Processing Weather Data for Record 7 of Set 7 | Danville
# Processing Weather Data for Record 8 of Set 7 | Yunhe
# Processing Weather Data for Record 9 of Set 7 | Dingle
# Processing Weather Data for Record 10 of Set 7 | Shakiso
# Processing Weather Data for Record 11 of Set 7 | Miles City
# Processing Weather Data for Record 12 of Set 7 | Vung Tau
# Processing Weather Data for Record 13 of Set 7 | Bonthe
# Processing Weather Data for Record 14 of Set 7 | Lüderitz
# City not found....Skipping............
# Processing Weather Data for Record 15 of Set 7 | Rosarito
# Processing Weather Data for Record 16 of Set 7 | Safranbolu
# City not found....Skipping............
# Processing Weather Data for Record 17 of Set 7 | Ostrovnoy
# Processing Weather Data for Record 18 of Set 7 | Lakatoro
# Processing Weather Data for Record 19 of Set 7 | Balkhash
# Processing Weather Data for Record 20 of Set 7 | Tomatlán
# Processing Weather Data for Record 21 of Set 7 | Olafsvik
# Processing Weather Data for Record 22 of Set 7 | Bud
# Processing Weather Data for Record 23 of Set 7 | Zyryanka
# Processing Weather Data for Record 24 of Set 7 | Uuemõisa
# Processing Weather Data for Record 25 of Set 7 | Sitka
# Processing Weather Data for Record 26 of Set 7 | Coquimbo
# City not found....Skipping............
# Processing Weather Data for Record 27 of Set 7 | Xining
# City not found....Skipping............
# Processing Weather Data for Record 28 of Set 7 | Dzhebariki-Khaya
# Processing Weather Data for Record 29 of Set 7 | Los Rastrojos
# Processing Weather Data for Record 30 of Set 7 | Kumluca
# Processing Weather Data for Record 31 of Set 7 | Birao
# Processing Weather Data for Record 32 of Set 7 | Presidencia Roque Sáenz Peña
# Processing Weather Data for Record 33 of Set 7 | Mount Isa
# Processing Weather Data for Record 34 of Set 7 | Deputatsky
# Processing Weather Data for Record 35 of Set 7 | Saquisilí
# Processing Weather Data for Record 36 of Set 7 | Adrar
# Processing Weather Data for Record 37 of Set 7 | Ahipara
# Processing Weather Data for Record 38 of Set 7 | Rocha
# Processing Weather Data for Record 39 of Set 7 | Chokurdakh
# Processing Weather Data for Record 40 of Set 7 | Imbituba
# Processing Weather Data for Record 41 of Set 7 | San José
# Processing Weather Data for Record 42 of Set 7 | Matagami
# Processing Weather Data for Record 43 of Set 7 | Dawei
# City not found....Skipping............
# Processing Weather Data for Record 44 of Set 7 | Águilas
# Processing Weather Data for Record 45 of Set 7 | Naruja
# Processing Weather Data for Record 46 of Set 7 | Luoyang
# Processing Weather Data for Record 47 of Set 7 | Uglich
# Processing Weather Data for Record 48 of Set 7 | Blackwater
# Processing Weather Data for Record 49 of Set 7 | East London
# Processing Weather Data for Record 50 of Set 7 | Khanbari
# Processing Weather Data for Record 1 of Set 8 | Sumbe
# City not found....Skipping............
# Processing Weather Data for Record 2 of Set 8 | Mahébourg
# Processing Weather Data for Record 3 of Set 8 | Dimāpur
# Processing Weather Data for Record 4 of Set 8 | Chernyshevsk
# Processing Weather Data for Record 5 of Set 8 | Saint George
# Processing Weather Data for Record 6 of Set 8 | Sisimiut
# Processing Weather Data for Record 7 of Set 8 | Hvide Sande
# City not found....Skipping............
# Processing Weather Data for Record 8 of Set 8 | Candiis
# Processing Weather Data for Record 9 of Set 8 | ‘Ewa Beach
# Processing Weather Data for Record 10 of Set 8 | Zaragoza
# City not found....Skipping............
# Processing Weather Data for Record 11 of Set 8 | Ankang
# City not found....Skipping............
# Processing Weather Data for Record 12 of Set 8 | Southbridge
# Processing Weather Data for Record 13 of Set 8 | Miquelon
# City not found....Skipping............
# Processing Weather Data for Record 14 of Set 8 | Savannah Bight
# Processing Weather Data for Record 15 of Set 8 | Zyryanovsk
# Processing Weather Data for Record 16 of Set 8 | Miraflores
# Processing Weather Data for Record 17 of Set 8 | Macau
# Processing Weather Data for Record 18 of Set 8 | Coahuayana Viejo
# Processing Weather Data for Record 19 of Set 8 | Fairbanks
# Processing Weather Data for Record 20 of Set 8 | Zhangye
# Processing Weather Data for Record 21 of Set 8 | Maningrida
# Processing Weather Data for Record 22 of Set 8 | Saint-Georges
# Processing Weather Data for Record 23 of Set 8 | Agüimes
# City not found....Skipping............
# Processing Weather Data for Record 24 of Set 8 | Manaus
# Processing Weather Data for Record 25 of Set 8 | Caxito
# Processing Weather Data for Record 26 of Set 8 | Richards Bay
# Processing Weather Data for Record 27 of Set 8 | Okhotsk
# Processing Weather Data for Record 28 of Set 8 | Jaguarari
# Processing Weather Data for Record 29 of Set 8 | Port Blair
# Processing Weather Data for Record 30 of Set 8 | Muisne
# Processing Weather Data for Record 31 of Set 8 | Contamana
# Processing Weather Data for Record 32 of Set 8 | Kazachinskoye
# Processing Weather Data for Record 33 of Set 8 | Najrān
# Processing Weather Data for Record 34 of Set 8 | Nkhotakota
# Processing Weather Data for Record 35 of Set 8 | Ashtian
# Processing Weather Data for Record 36 of Set 8 | Souillac
# City not found....Skipping............
# Processing Weather Data for Record 37 of Set 8 | Rabat
# Processing Weather Data for Record 38 of Set 8 | La Joya
# Processing Weather Data for Record 39 of Set 8 | Makkah al Mukarramah
# Processing Weather Data for Record 40 of Set 8 | Ubalá
# Processing Weather Data for Record 41 of Set 8 | Corinto
# Processing Weather Data for Record 42 of Set 8 | Cape Canaveral
# Processing Weather Data for Record 43 of Set 8 | Svetogorsk
# Processing Weather Data for Record 44 of Set 8 | Diapaga
# Processing Weather Data for Record 45 of Set 8 | Road Town
# Processing Weather Data for Record 46 of Set 8 | Priladozhskiy
# City not found....Skipping............
# Processing Weather Data for Record 47 of Set 8 | Ølen
# Processing Weather Data for Record 48 of Set 8 | Khiv
# Processing Weather Data for Record 49 of Set 8 | Alofi
# Processing Weather Data for Record 50 of Set 8 | Pirapora
# Processing Weather Data for Record 1 of Set 9 | Vila do Maio
# Processing Weather Data for Record 2 of Set 9 | Quthing
# Processing Weather Data for Record 3 of Set 9 | Wanning
# Processing Weather Data for Record 4 of Set 9 | Mandera
# Processing Weather Data for Record 5 of Set 9 | Derby
# Processing Weather Data for Record 6 of Set 9 | Rochegda
# Processing Weather Data for Record 7 of Set 9 | Sesto Calende
# Processing Weather Data for Record 8 of Set 9 | Coyhaique
# Processing Weather Data for Record 9 of Set 9 | Chissamba
# Processing Weather Data for Record 10 of Set 9 | Buluang
# Processing Weather Data for Record 11 of Set 9 | Worland
# Processing Weather Data for Record 12 of Set 9 | São João da Barra
# Processing Weather Data for Record 13 of Set 9 | Port Huron
# Processing Weather Data for Record 14 of Set 9 | Kumul
# Processing Weather Data for Record 15 of Set 9 | Nikel
# Processing Weather Data for Record 16 of Set 9 | Ola
# Processing Weather Data for Record 17 of Set 9 | Havre
# Processing Weather Data for Record 18 of Set 9 | Dubbo
# Processing Weather Data for Record 19 of Set 9 | Mount Gambier
# Processing Weather Data for Record 20 of Set 9 | Qaqortoq
# Processing Weather Data for Record 21 of Set 9 | Nyaunglebin
# Processing Weather Data for Record 22 of Set 9 | Lamu
# Processing Weather Data for Record 23 of Set 9 | Saint-Augustin
# Processing Weather Data for Record 24 of Set 9 | Lengshuitan
# Processing Weather Data for Record 25 of Set 9 | Jāmai
# Processing Weather Data for Record 26 of Set 9 | Nanchang
# Processing Weather Data for Record 27 of Set 9 | Skibbereen
# Processing Weather Data for Record 28 of Set 9 | Tabuk
# Processing Weather Data for Record 29 of Set 9 | Havøysund
# Processing Weather Data for Record 30 of Set 9 | Ordzhonikidze
# Processing Weather Data for Record 31 of Set 9 | Robertsport
# Processing Weather Data for Record 32 of Set 9 | Afuá
# Processing Weather Data for Record 33 of Set 9 | Cortez
# Processing Weather Data for Record 34 of Set 9 | Hamilton
# City not found....Skipping............
# City not found....Skipping............
# Processing Weather Data for Record 35 of Set 9 | Yertsevo
# Processing Weather Data for Record 36 of Set 9 | Jiujiang
# Processing Weather Data for Record 37 of Set 9 | Benguela
# Processing Weather Data for Record 38 of Set 9 | Margate
# Processing Weather Data for Record 39 of Set 9 | Khandyga
# City not found....Skipping............
# Processing Weather Data for Record 40 of Set 9 | Lagunas
# Processing Weather Data for Record 41 of Set 9 | Ringkøbing
# Processing Weather Data for Record 42 of Set 9 | Antalaha
# Processing Weather Data for Record 43 of Set 9 | College
# City not found....Skipping............
# Processing Weather Data for Record 44 of Set 9 | Thompson
# Processing Weather Data for Record 45 of Set 9 | Huarmey
# Processing Weather Data for Record 46 of Set 9 | Brainerd
# Processing Weather Data for Record 47 of Set 9 | Chumphon
# Processing Weather Data for Record 48 of Set 9 | Ulaangom
# Processing Weather Data for Record 49 of Set 9 | Mīnāb
# Processing Weather Data for Record 50 of Set 9 | Carutapera
# Processing Weather Data for Record 1 of Set 10 | Ust'-Ilimsk
# City not found....Skipping............
# Processing Weather Data for Record 2 of Set 10 | Antsohihy
# Processing Weather Data for Record 3 of Set 10 | Djenné
# Processing Weather Data for Record 4 of Set 10 | Bako
# Processing Weather Data for Record 5 of Set 10 | Villars-sur-Glâne
# Processing Weather Data for Record 6 of Set 10 | Chany
# Processing Weather Data for Record 7 of Set 10 | Vol'sk
# City not found....Skipping............
# City not found....Skipping............
# Processing Weather Data for Record 8 of Set 10 | Břidličná
# Processing Weather Data for Record 9 of Set 10 | Los Llanos de Aridane
# Processing Weather Data for Record 10 of Set 10 | Leh
# Processing Weather Data for Record 11 of Set 10 | Boende
# Processing Weather Data for Record 12 of Set 10 | Nizhniy Tsasuchey
# Processing Weather Data for Record 13 of Set 10 | Scarborough
# Processing Weather Data for Record 14 of Set 10 | Sampit
# Processing Weather Data for Record 15 of Set 10 | Sibolga
# Processing Weather Data for Record 16 of Set 10 | Port-Gentil
# Processing Weather Data for Record 17 of Set 10 | Bocas del Toro
# Processing Weather Data for Record 18 of Set 10 | Gondanglegi
# Processing Weather Data for Record 19 of Set 10 | Montes Claros
# Processing Weather Data for Record 20 of Set 10 | Tilichiki
# City not found....Skipping............
# Processing Weather Data for Record 21 of Set 10 | Zeya
# City not found....Skipping............
# Processing Weather Data for Record 22 of Set 10 | Acapetahua
# Processing Weather Data for Record 23 of Set 10 | Constitucion
# Processing Weather Data for Record 24 of Set 10 | Pindiga
# Processing Weather Data for Record 25 of Set 10 | Parintins
# City not found....Skipping............
# Processing Weather Data for Record 26 of Set 10 | Yaring
# Processing Weather Data for Record 27 of Set 10 | Watertown
# Processing Weather Data for Record 28 of Set 10 | San Ramón
# Processing Weather Data for Record 29 of Set 10 | Lichinga
# Processing Weather Data for Record 30 of Set 10 | Saint-Pierre
# Processing Weather Data for Record 31 of Set 10 | Hobyo
# Processing Weather Data for Record 32 of Set 10 | Muli
# Processing Weather Data for Record 33 of Set 10 | Uthai Thani
# Processing Weather Data for Record 34 of Set 10 | Manokwari
# Processing Weather Data for Record 35 of Set 10 | Ballina
# Processing Weather Data for Record 36 of Set 10 | Araouane
# Processing Weather Data for Record 37 of Set 10 | Paamiut
# Processing Weather Data for Record 38 of Set 10 | Chernyshevskiy
# City not found....Skipping............
# Processing Weather Data for Record 39 of Set 10 | Nipawin
# City not found....Skipping............
# Processing Weather Data for Record 40 of Set 10 | Katangli
# Processing Weather Data for Record 41 of Set 10 | Kabanjahe
# Processing Weather Data for Record 42 of Set 10 | Lima
# Processing Weather Data for Record 43 of Set 10 | Artvin Province
# Processing Weather Data for Record 44 of Set 10 | Scottsboro
# Processing Weather Data for Record 45 of Set 10 | Dicabisagan
# Processing Weather Data for Record 46 of Set 10 | Colomi
# Processing Weather Data for Record 47 of Set 10 | Concepción de Buenos Aires
# City not found....Skipping............
# Processing Weather Data for Record 48 of Set 10 | Atar
# Processing Weather Data for Record 49 of Set 10 | Libreville
# Processing Weather Data for Record 50 of Set 10 | Cambará
# Processing Weather Data for Record 1 of Set 11 | San Rafael del Sur
# Processing Weather Data for Record 2 of Set 11 | Baraboo
# Processing Weather Data for Record 3 of Set 11 | Puerto Palomas
# Processing Weather Data for Record 4 of Set 11 | Tigil'
# Processing Weather Data for Record 5 of Set 11 | Shagonar
# Processing Weather Data for Record 6 of Set 11 | Beringovskiy
# Processing Weather Data for Record 7 of Set 11 | Groningen
# Processing Weather Data for Record 8 of Set 11 | Pochutla
# Processing Weather Data for Record 9 of Set 11 | Karpathos
# Processing Weather Data for Record 10 of Set 11 | Laurens
# Processing Weather Data for Record 11 of Set 11 | Caravelas
# Processing Weather Data for Record 12 of Set 11 | Kariba
# Processing Weather Data for Record 13 of Set 11 | Presidente Epitácio
# Processing Weather Data for Record 14 of Set 11 | Linqiong
# Processing Weather Data for Record 15 of Set 11 | Puerto Carreño
# Processing Weather Data for Record 16 of Set 11 | Msanga
# Processing Weather Data for Record 17 of Set 11 | Jalu
# Processing Weather Data for Record 18 of Set 11 | Tougue
# City not found....Skipping............
# Processing Weather Data for Record 19 of Set 11 | Haradok
# Processing Weather Data for Record 20 of Set 11 | Camocim
# City not found....Skipping............
# Processing Weather Data for Record 21 of Set 11 | Puerto Varas
# Processing Weather Data for Record 22 of Set 11 | Stornoway
# Processing Weather Data for Record 23 of Set 11 | Tynda
# Processing Weather Data for Record 24 of Set 11 | Carnot
# Processing Weather Data for Record 25 of Set 11 | Maku
# Processing Weather Data for Record 26 of Set 11 | Terrenate
# Processing Weather Data for Record 27 of Set 11 | Sirūr
# Processing Weather Data for Record 28 of Set 11 | Sokoni
# Processing Weather Data for Record 29 of Set 11 | Changji
# Processing Weather Data for Record 30 of Set 11 | Tondi
# Processing Weather Data for Record 31 of Set 11 | Hīt
# Processing Weather Data for Record 32 of Set 11 | Bumba
# Processing Weather Data for Record 33 of Set 11 | Nabire
# Processing Weather Data for Record 34 of Set 11 | Mogadishu
# Processing Weather Data for Record 35 of Set 11 | Comodoro Rivadavia
# Processing Weather Data for Record 36 of Set 11 | Mogwase
# Processing Weather Data for Record 37 of Set 11 | Uni
# Processing Weather Data for Record 38 of Set 11 | Lompoc
# Processing Weather Data for Record 39 of Set 11 | Korla
# Processing Weather Data for Record 40 of Set 11 | Honiara
# City not found....Skipping............
# City not found....Skipping............
# Processing Weather Data for Record 41 of Set 11 | Makat
# City not found....Skipping............
# Processing Weather Data for Record 42 of Set 11 | Labytnangi
#
# -----------------------------
# Data Retrival Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Clean dataframe to remove cities that were not found
city_weather['Max Temp'] = city_weather['Max Temp'].replace('', np.nan)
city_weather = city_weather.dropna()

#Save dataframe
city_weather.to_csv(output_data_file, index=False, header=True)

#Preview the dataframe
city_weather.head()
# Out:
#            City Cloudiness Country        Date Humidity      Lat       Lng  \
# 0       beterou        100      BJ  1635298737       86   9.1992    2.2586
# 1    sao filipe         61      CV  1635298738       77  14.8961  -24.4956
# 4  punta arenas          0      CL  1635298661       70   -53.15  -70.9167
# 5       dunedin         80      NZ  1635298739       83 -45.8742  170.5036
# 6          chik         20      RU  1635298739       63  54.9928   82.4311
#
#    Max Temp Windspeed
# 0     74.84      3.33
# 1     78.93     11.36
# 4     42.91     14.97
# 5     57.54      4.52
# 6     28.18     11.18

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_weather["Lat"], city_weather["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title(f'City Latitude vs. Max Temperature')
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("City Latitude vs. Max Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_weather["Lat"], city_weather["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title(f'City Latitude vs. Humidity')
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("City Latitude vs. Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_weather["Lat"], city_weather["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title(f'City Latitude vs. Max Cloudiness')
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("City Latitude vs. Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_weather["Lat"], city_weather["Windspeed"], marker="o")

# Incorporate the other graph properties
plt.title(f'City Latitude vs. Wind Speed {time.strftime("%m/%d/%Y")}')
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("City Latitude vs. Wind Speed.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = city_weather.loc[pd.to_numeric(city_weather["Lat"]).astype(float) > 0, :]
southern_df = city_weather.loc[pd.to_numeric(city_weather["Lat"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")
plt.show()
# Out:
# Regression line equation is: y = -0.94x + 89.98
# The r-squared is: -0.8814007525447242
# The regression displays a negative correlation.
# In the nothern hemisphere, as you move away from the equator the temperature decreases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the southern hemisphere, as you get closer to the equator the temperature increases.")
plt.show()
# Out:
# Regression line equation is: y = 0.4x + 79.61
# The r-squared is: 0.5274121655484354
# The regression displays a positive correlation.
# In the southern hemisphere, as you get closer to the equator the temperature increases.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.") 
plt.show()
# Out:
# Regression line equation is: y = 0.13x + 69.87
# The r-squared is: 0.14402797304274834
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.37x + 77.84
# The r-squared is: 0.2721359378193111
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.32x + 48.85
# The r-squared is: 0.16587819283878974
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.45x + 58.79
# The r-squared is: 0.1549319862039307
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Windspeed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.07x + 5.21
# The r-squared is: 0.21051144358259136
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Windspeed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = -0.09x + 6.27
# The r-squared is: -0.24460585996584605
# The regression does not display much of a correlation between the data sets.
